# %% [markdown]
# # Prediction with ForceRegression model

# %%
# %load imports.py
# %load_ext autoreload
# %autoreload 2
# %load_ext kedro.extras.extensions.ipython
# %reload_kedro /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models
# %config Completer.use_jedi = False  ## (To fix autocomplete)
import pandas as pd
from vessel_manoeuvring_models.models.vmm import ModelSimulator
import matplotlib.pyplot as plt

# %matplotlib inline
from vessel_manoeuvring_models.visualization.plot import track_plots, plot, captive_plot
import kedro
import numpy as np
import os.path
import anyconfig

import matplotlib

matplotlib.rcParams["figure.figsize"] = (15, 4)
from vessel_manoeuvring_models.symbols import *

# Read configs:
conf_path = os.path.join("../conf/base/")
runs_globals_path = os.path.join(
    conf_path,
    "runs_globals.yml",
)

runs_globals = anyconfig.load(runs_globals_path)
model_test_ids = runs_globals["model_test_ids"]

join_globals_path = os.path.join(
    conf_path,
    "join_globals.yml",
)

joins = runs_globals["joins"]
join_runs_dict = anyconfig.load(join_globals_path)

globals_path = os.path.join(
    conf_path,
    "globals.yml",
)
global_variables = anyconfig.load(globals_path)


vmms = global_variables["vmms"]
only_joined = global_variables[
    "only_joined"
]  # (regress/predict with only models from joined runs)S
# Out:
# 2026-04-01 22:36:38,789 - kedro.framework.session.store - INFO - `read()` not implemented for `SQLiteStore`. Assuming empty store.
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/framework/context/context.py:488: UserWarning: Credentials not found in your Kedro project config.
# No files found in ['/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/base', '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/local'] matching the glob pattern(s): ['credentials*', 'credentials*/**', '**/credentials*']
#   warn(f"Credentials not found in your Kedro project config.\n{str(exc)}")
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/plotly/express/imshow_utils.py:24: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
# 2026-04-01 22:37:13,255 - root - INFO - ** Kedro project wPCC_pipeline
# 2026-04-01 22:37:13,265 - root - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`
# 2026-04-01 22:37:24,509 - root - INFO - Registered line magic `run_viz`
# 2026-04-01 22:37:26,046 - kedro.framework.session.store - INFO - `read()` not implemented for `SQLiteStore`. Assuming empty store.
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/framework/context/context.py:488: UserWarning: Credentials not found in your Kedro project config.
# No files found in ['/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/base', '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/local'] matching the glob pattern(s): ['credentials*', 'credentials*/**', '**/credentials*']
#   warn(f"Credentials not found in your Kedro project config.\n{str(exc)}")
# 2026-04-01 22:37:33,271 - root - INFO - ** Kedro project wPCC_pipeline
# 2026-04-01 22:37:33,276 - root - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`
# 2026-04-01 22:37:33,358 - root - INFO - Registered line magic `run_viz`

# %%
id = "22773"
# id = "22774"
# vmm_name = "vmm_martin"
vmm_name = "vmm_martins_simple"

df = catalog.load(f"wpcc.{id}.data")
df_smooth = catalog.load(f"wpcc.updated.{id}.data_ek_smooth")
model = catalog.load(f"{vmm_name}.force_regression.model")
regression = catalog.load(f"{vmm_name}.force_regression.regression")
df_VCT = catalog.load("force_regression.data_scaled")
ship_data = catalog.load("ship_data")

model_motion_regression = catalog.load(f"{vmm_name}.motion_regression.joined.model")


motion_regression = catalog.load(f"{vmm_name}.motion_regression.joined.regression")
force_regression = catalog.load(f"{vmm_name}.force_regression.regression")
# keys_forces = ['fx','fy','fz']
# scale_factor=ship_data['scale_factor']
# forces=df_VCT[keys_forces]
# df_VCT[keys_forces] = scale_force_to_model_scale(forces=forces, scale_factor=scale_factor, **df_VCT)
# keys_moments = ['mx','my','mz']
# df_VCT[keys_moments] = scale_force_to_model_scale(df_VCT[keys_moments], scale_factor=scale_factor, **df_VCT)
# Out:
# 2026-04-01 22:37:46,232 - kedro.io.data_catalog - INFO - Loading data from `wpcc.22773.data` (CSVDataSet)...
# 2026-04-01 22:37:46,358 - kedro.io.data_catalog - INFO - Loading data from `wpcc.updated.22773.data_ek_smooth` (CSVDataSet)...
# 2026-04-01 22:37:46,473 - kedro.io.data_catalog - INFO - Loading data from `vmm_martins_simple.force_regression.model` (PickleDataSet)...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/io/core.py in load(self)
#     181         try:
# --> 182             return self._load()
#     183         except DataSetError:
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/extras/datasets/pickle/pickle_dataset.py in _load(self)
#     204
# --> 205         with self._fs.open(load_path, **self._fs_open_args_load) as fs_file:
#     206             return self._backend.load(fs_file, **self._load_args)  # type: ignore
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1029             ac = kwargs.pop("autocommit", not self._intrans)
# -> 1030             f = self._open(
#    1031                 path,
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/fsspec/implementations/local.py in _open(self, path, mode, block_size, **kwargs)
#     154             self.makedirs(self._parent(path), exist_ok=True)
# --> 155         return LocalFileOpener(path, mode, fs=self, **kwargs)
#     156
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/fsspec/implementations/local.py in __init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     249         self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 250         self._open()
#     251
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/fsspec/implementations/local.py in _open(self)
#     254             if self.autocommit or "w" not in self.mode:
# --> 255                 self.f = open(self.path, mode=self.mode)
#     256                 if self.compression:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/data/06_models/vmm_martins_simple/force_regression/vmm_martins_simple.force_regression.model.pkl'
#
# The above exception was the direct cause of the following exception:
#
# DataSetError                              Traceback (most recent call last)
# /tmp/ipykernel_7877/2343982348.py in <module>
#       6 df = catalog.load(f"wpcc.{id}.data")
#       7 df_smooth = catalog.load(f"wpcc.updated.{id}.data_ek_smooth")
# ----> 8 model = catalog.load(f"{vmm_name}.force_regression.model")
#       9 regression = catalog.load(f"{vmm_name}.force_regression.regression")
#      10 df_VCT = catalog.load("force_regression.data_scaled")
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py in load(self, name, version)
#     395
#     396         func = self._get_transformed_dataset_function(name, "load", dataset)
# --> 397         result = func()
#     398
#     399         version = (
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/io/core.py in load(self)
#     593     def load(self) -> Any:
#     594         self.resolve_load_version()  # Make sure last load version is set
# --> 595         return super().load()
#     596
#     597     def save(self, data: Any) -> None:
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/io/core.py in load(self)
#     189                 f"Failed while loading data from data set {str(self)}.\n{str(exc)}"
#     190             )
# --> 191             raise DataSetError(message) from exc
#     192
#     193     def save(self, data: Any) -> None:
#
# DataSetError: Failed while loading data from data set PickleDataSet(backend=<module 'dill' from '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/dill/__init__.py'>, filepath=/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/data/06_models/vmm_martins_simple/force_regression/vmm_martins_simple.force_regression.model.pkl, load_args={}, protocol=file, save_args={}).
# [Errno 2] No such file or directory: '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/data/06_models/vmm_martins_simple/force_regression/vmm_martins_simple.force_regression.model.pkl'

# %%
motion_regression.parameters

# %%
motion_regression.model_X.summary()

# %%
force_regression.parameters

# %%
force_regression.model_Y.summary()

# %%
force_regression.model_Y.cov_HC0

# %%
force_regression.model_Y.bse

# %%
from scipy.stats import norm, multivariate_normal

# %%
rv = norm(
    loc=force_regression.model_Y.params["Yv"], scale=force_regression.model_Y.bse["Yv"]
)
rv.interval(alpha=0.95)

# %%
bse = force_regression.model_X.bse

means = force_regression.model_X.params
means = means.append(force_regression.model_Y.params)
means = means.append(force_regression.model_N.params)

stds = force_regression.model_X.bse
stds = stds.append(force_regression.model_Y.bse)
stds = stds.append(force_regression.model_N.bse)

mask = stds > 10**-10
means = means[mask].copy()
stds = stds[mask].copy()

# %%
cov = np.diag(stds.values**2)
rv = multivariate_normal(mean=means, cov=cov)

# %%
df_parameter_variation = pd.DataFrame(data=rv.rvs(10), columns=means.index)

# %%
df_parameter_variation.head()

# %%
models = {}
results = {}
# for index, parameters in df_parameter_variation.iterrows():
#
#    model_ = model.copy()
#    model_.parameters.update(parameters)
#
#    try:
#        result = model_.simulate(df_=df_smooth)
#    except:
#        continue
#
#    models[index] = model_
#    results[index] = result.result
#

# %%
# dataframes = {
#'model test' : df_smooth,
# }
#
# dataframes.update(results)
#
# styles = {key:{'style':'r-','alpha':0.3} for key in dataframes}
# styles['model test'] = {'style':'b-', 'alpha':1, 'zorder':-10}
#
# fig,ax=plt.subplots()
# track_plots(dataframes=dataframes, lpp=model.ship_parameters['L'], beam=model.ship_parameters['B'], ax=ax, plot_boats=False, styles=styles);
#
# plot(dataframes, keys=result.result.columns);

# %%
parameters = force_regression.parameters
parameters["yerr"] = (
    parameters["$conf_{higher}$"] - parameters["$conf_{lower}$"]
).abs()
parameters.plot.bar(y="regressed", yerr=parameters["yerr"])

# %%
parameters.plot.bar(y="$P_{value}$")

# %%
df_VCT[["u", "v", "V", "r", "fx", "fy", "mz"]].abs().max()

# %%
df_parameters = pd.DataFrame()
df_parameters["force regression"] = model.parameters
df_parameters["motion regression"] = model_motion_regression.parameters
df_parameters

# %%
drops = [key for key in df_parameters.index if "dot" in key]
drops.append("Xthrust")
df_parameters_plot = df_parameters.drop(index=drops)
df_parameters_plot.plot(kind="bar")

# %%
# model.parameters['Xu'] = -0.000737*1.7
result = model.simulate(df_=df_smooth)
result2 = model_motion_regression.simulate(df_=df_smooth)

# %%
# model_hybrid = model.copy()
# steals = ['Xvr']
#
# for steal in steals:
#    model_hybrid.parameters[steal] = model_motion_regression.parameters[steal]
#
# result_hybrid = model_hybrid.simulate(df_=df_smooth)

# %%
dataframes = {
    "model test": df_smooth,
    "simulation (force regression)": result.result,
    "simulation (motion regression)": result2.result,
    #'simulation (hybrid)' : result_hybrid.result,
}

fig, ax = plt.subplots()
track_plots(
    dataframes=dataframes,
    lpp=model.ship_parameters["L"],
    beam=model.ship_parameters["B"],
    ax=ax,
    plot_boats=False,
)
plot(dataframes, keys=result.result.columns);

# %%
catalog.load(f"{vmm_name}.motion_regression.joined.{id}.simulation_accuracy")

# %%
regressions = global_variables["regressions"]

regression_names = ["motion_regression", "force_regression"]

df_accuracies = pd.DataFrame()

for vmm_name in vmms:
    for model_test_id in model_test_ids:
        file_paths = []
        file_paths.append(
            f"{vmm_name}.motion_regression.joined.{model_test_id}.simulation_accuracy"
        )
        file_paths.append(
            f"{vmm_name}.force_regression.{model_test_id}.simulation_accuracy"
        )

        for regression, file_path in zip(regression_names, file_paths):
            try:
                accuracy = catalog.load(file_path)
            except:
                continue

            accuracy = pd.Series(accuracy)
            accuracy["total"] = accuracy.mean()

            accuracy["vmm"] = vmm_name
            accuracy["regression"] = regression
            accuracy["model test"] = model_test_id

            df_accuracies = df_accuracies.append(accuracy, ignore_index=True)

# %%
df_compare = (
    df_accuracies.groupby(by=["vmm", "regression"])
    .mean()
    .sort_values(by="total", ascending=True)
)
df_compare

# %%
df_compare["total"].plot.bar()

# %%
df_compare.reset_index().pivot(
    index=["vmm"], columns=["regression"], values="total"
).plot.bar();
