# %% [markdown]
# # Damping forces from models

# %%
# %load imports.py
# %load_ext autoreload
# %autoreload 2
# %load_ext kedro.extras.extensions.ipython
# %reload_kedro ./System-identification-of-Vessel-Manoeuvring-Models
import pandas as pd
from vessel_manoeuvring_models.models.vmm import ModelSimulator
import matplotlib.pyplot as plt

# %matplotlib inline
from vessel_manoeuvring_models.visualization.plot import track_plots, plot, captive_plot
import kedro
import numpy as np

import matplotlib

matplotlib.rcParams["figure.figsize"] = (15, 4)
from vessel_manoeuvring_models.symbols import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The kedro.extras.extensions.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.extras.extensions.ipython

# %%
def get_dataset_name(vmm="vmm_linear", regression="force_regression", id=22773):
    jinja = "{{ vmm }}.{{ regression }}.{{ id }}.data_damping_forces"
    template = jinja.replace(r"{{", "{").replace(r"}}", "}")

    return eval(f"f'{template}'")


def get_dataset(vmm="vmm_linear", regression="force_regression", id=22773):

    name = get_dataset_name(vmm=vmm, regression=regression, id=id)
    return catalog.load(name)


def get_dataset_name_joined(
    vmm="vmm_linear", regression="force_regression", id=22773, join_name="joined"
):
    jinja = "{{ vmm }}.{{ regression }}.{{ join_name }}.{{ id }}.data_damping_forces"
    template = jinja.replace(r"{{", "{").replace(r"}}", "}")

    return eval(f"f'{template}'")


def get_dataset_joined(vmm="vmm_linear", regression="force_regression", id=22773):

    name = get_dataset_name(vmm=vmm, regression=regression, id=id)
    return catalog.load(name)

# %%
df_VCT = catalog.load("force_regression.data_scaled_resistance_corrected")
df_VCT["item"] = "VCT"
# data = df_VCT[['fx','fy','mz','u','v','V','r','beta','delta','thrust','test type']].copy()
# data['item'] = 'VCT'
data = pd.DataFrame()


# vmms = ['vmm_martin']
vmms = ["vmm_martins_simple"]
# vmms = ['vmm_linear']
model_test_ids = [22773]

for vmm in vmms:
    data_ = get_dataset(vmm=vmm)
    data_["item"] = get_dataset_name(vmm=vmm)
    data = data.append(data_)

for vmm in vmms:
    data_ = get_dataset_joined(vmm=vmm, regression="motion_regression")
    data_["item"] = get_dataset_name_joined(
        vmm=vmm, regression="motion_regression", join_name="joined"
    )
    data = data.append(data_)

data.append(df_VCT)
# Out:
# 2026-05-19 18:38:26,493 - kedro.io.data_catalog - INFO - Loading data from `force_regression.data_scaled_resistance_corrected` (CSVDataSet)...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/io/core.py in load(self)
#     181         try:
# --> 182             return self._load()
#     183         except DataSetError:
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/extras/datasets/pandas/csv_dataset.py in _load(self)
#     153
# --> 154         with self._fs.open(load_path, **self._fs_open_args_load) as fs_file:
#     155             return pd.read_csv(fs_file, **self._load_args)
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1029             ac = kwargs.pop("autocommit", not self._intrans)
# -> 1030             f = self._open(
#    1031                 path,
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/fsspec/implementations/local.py in _open(self, path, mode, block_size, **kwargs)
#     154             self.makedirs(self._parent(path), exist_ok=True)
# --> 155         return LocalFileOpener(path, mode, fs=self, **kwargs)
#     156
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/fsspec/implementations/local.py in __init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     249         self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 250         self._open()
#     251
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/fsspec/implementations/local.py in _open(self)
#     254             if self.autocommit or "w" not in self.mode:
# --> 255                 self.f = open(self.path, mode=self.mode)
#     256                 if self.compression:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/data/02_intermediate/force_regression.data_scaled_resistance_corrected.csv'
#
# The above exception was the direct cause of the following exception:
#
# DataSetError                              Traceback (most recent call last)
# /tmp/ipykernel_14136/1960471557.py in <module>
# ----> 1 df_VCT = catalog.load("force_regression.data_scaled_resistance_corrected")
#       2 df_VCT["item"] = "VCT"
#       3 # data = df_VCT[['fx','fy','mz','u','v','V','r','beta','delta','thrust','test type']].copy()
#       4 # data['item'] = 'VCT'
#       5 data = pd.DataFrame()
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py in load(self, name, version)
#     395
#     396         func = self._get_transformed_dataset_function(name, "load", dataset)
# --> 397         result = func()
#     398
#     399         version = (
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/io/core.py in load(self)
#     593     def load(self) -> Any:
#     594         self.resolve_load_version()  # Make sure last load version is set
# --> 595         return super().load()
#     596
#     597     def save(self, data: Any) -> None:
#
# ~/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/io/core.py in load(self)
#     189                 f"Failed while loading data from data set {str(self)}.\n{str(exc)}"
#     190             )
# --> 191             raise DataSetError(message) from exc
#     192
#     193     def save(self, data: Any) -> None:
#
# DataSetError: Failed while loading data from data set CSVDataSet(filepath=/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/data/02_intermediate/force_regression.data_scaled_resistance_corrected.csv, load_args={'index_col': 0}, protocol=file, save_args={'index': True}).
# [Errno 2] No such file or directory: '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/data/02_intermediate/force_regression.data_scaled_resistance_corrected.csv'

# %%
import plotly.express as px
from vessel_manoeuvring_models.visualization.plot import test_type_xplot

V = data.groupby(by="V")["item"].count().sort_values().index[-1]
data_V = data.groupby(by="V").get_group(V).copy()

data_V["v*r"] = data_V["v"] * data_V["r"]
data_V["beta"] = -np.arctan2(data_V["v"], data_V["u"])

key = "mz"

for test_type, df in data_V.groupby(by="test type"):
    if test_type == "resistance":
        continue

    x = test_type_xplot.get(test_type, "delta")
    fig = px.line(
        df.sort_values(by=x),
        x=x,
        y=key,
        color="item",
        width=1200,
        height=300,
        title=test_type,
    )
    fig.show()

fig = px.line(
    data.groupby(by="test type").get_group("resistance").sort_values(by="u"),
    x="u",
    y="fx",
    color="item",
    width=1200,
    height=300,
    title="resistance",
)
fig.show()

# %%
captive_plot(data, styles=["-", "--", "o"])

# %%
data.groupby(by=["test type"]).get_group("resistance")
