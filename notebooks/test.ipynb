# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext kedro.extras.extensions.ipython
# %reload_kedro /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models
# %matplotlib inline
import pandas as pd
from vessel_manoeuvring_models.models.vmm import ModelSimulator
import matplotlib.pyplot as plt
from vessel_manoeuvring_models.visualization.plot import track_plots, plot
import kedro

import matplotlib

matplotlib.rcParams["figure.figsize"] = (15, 4)
# Out:
# 2026-05-21 10:45:29,837 - kedro.framework.session.store - INFO - `read()` not implemented for `SQLiteStore`. Assuming empty store.
# 2026-05-21 10:45:29,837 - kedro.framework.session.store - INFO - `read()` not implemented for `SQLiteStore`. Assuming empty store.
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/framework/context/context.py:488: UserWarning: Credentials not found in your Kedro project config.
# No files found in ['/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/base', '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/local'] matching the glob pattern(s): ['credentials*', 'credentials*/**', '**/credentials*']
#   warn(f"Credentials not found in your Kedro project config.\n{str(exc)}")
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/plotly/express/imshow_utils.py:24: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
# 2026-05-21 10:45:29,837 - kedro.framework.session.store - INFO - `read()` not implemented for `SQLiteStore`. Assuming empty store.
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/framework/context/context.py:488: UserWarning: Credentials not found in your Kedro project config.
# No files found in ['/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/base', '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/local'] matching the glob pattern(s): ['credentials*', 'credentials*/**', '**/credentials*']
#   warn(f"Credentials not found in your Kedro project config.\n{str(exc)}")
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/plotly/express/imshow_utils.py:24: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
# 2026-05-21 10:45:34,283 - root - INFO - ** Kedro project wPCC_pipeline
# 2026-05-21 10:45:34,284 - root - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`
# 2026-05-21 10:45:35,778 - root - INFO - Registered line magic `run_viz`
# 2026-05-21 10:45:36,050 - kedro.framework.session.store - INFO - `read()` not implemented for `SQLiteStore`. Assuming empty store.
# 2026-05-21 10:45:29,837 - kedro.framework.session.store - INFO - `read()` not implemented for `SQLiteStore`. Assuming empty store.
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/framework/context/context.py:488: UserWarning: Credentials not found in your Kedro project config.
# No files found in ['/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/base', '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/local'] matching the glob pattern(s): ['credentials*', 'credentials*/**', '**/credentials*']
#   warn(f"Credentials not found in your Kedro project config.\n{str(exc)}")
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/plotly/express/imshow_utils.py:24: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
# 2026-05-21 10:45:34,283 - root - INFO - ** Kedro project wPCC_pipeline
# 2026-05-21 10:45:34,284 - root - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`
# 2026-05-21 10:45:35,778 - root - INFO - Registered line magic `run_viz`
# 2026-05-21 10:45:36,050 - kedro.framework.session.store - INFO - `read()` not implemented for `SQLiteStore`. Assuming empty store.
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/framework/context/context.py:488: UserWarning: Credentials not found in your Kedro project config.
# No files found in ['/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/base', '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/local'] matching the glob pattern(s): ['credentials*', 'credentials*/**', '**/credentials*']
#   warn(f"Credentials not found in your Kedro project config.\n{str(exc)}")
# 2026-05-21 10:45:29,837 - kedro.framework.session.store - INFO - `read()` not implemented for `SQLiteStore`. Assuming empty store.
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/framework/context/context.py:488: UserWarning: Credentials not found in your Kedro project config.
# No files found in ['/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/base', '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/local'] matching the glob pattern(s): ['credentials*', 'credentials*/**', '**/credentials*']
#   warn(f"Credentials not found in your Kedro project config.\n{str(exc)}")
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1846: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])  # type: ignore[arg-type]
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/plotly/express/imshow_utils.py:24: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
# 2026-05-21 10:45:34,283 - root - INFO - ** Kedro project wPCC_pipeline
# 2026-05-21 10:45:34,284 - root - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`
# 2026-05-21 10:45:35,778 - root - INFO - Registered line magic `run_viz`
# 2026-05-21 10:45:36,050 - kedro.framework.session.store - INFO - `read()` not implemented for `SQLiteStore`. Assuming empty store.
# /home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/.venv/lib/python3.10/site-packages/kedro/framework/context/context.py:488: UserWarning: Credentials not found in your Kedro project config.
# No files found in ['/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/base', '/home/sim/Documents/git_repos/SI_VMM/System-identification-of-Vessel-Manoeuvring-Models/conf/local'] matching the glob pattern(s): ['credentials*', 'credentials*/**', '**/credentials*']
#   warn(f"Credentials not found in your Kedro project config.\n{str(exc)}")
# 2026-05-21 10:45:36,909 - root - INFO - ** Kedro project wPCC_pipeline
# 2026-05-21 10:45:36,911 - root - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`
# 2026-05-21 10:45:36,920 - root - INFO - Registered line magic `run_viz`

# %%
from wPCC_pipeline.pipeline_registry import register_pipelines
pipelines = register_pipelines()
display(pipelines.keys())
# for node in pipelines["kvlcc2_hsva"].nodes:
    # print(f"{node.name}: {node.inputs} --> {node.outputs}")

# print(pipelines["wpcc"])
# Out:
# dict_keys(['__default__', 'USV', 'kvlcc2_hsva', 'wpcc', 'plot_wpcc', 'plot_kvlcc2', 'plot_kvlcc2_hsva', 'plot_USV', 'plot_filters_wpcc', 'plot_filters_kvlcc2', 'plot_filters_kvlcc2_hsva', 'plot_filters_USV', 'kvlcc2_hsva_create', 'work', 'plot', 'lowpass_study'])

# %%
names = [
    "vmm_abkowitz",
    "vmm_linear"
]
# ds = catalog._datasets[name]

for name in names:
    obj = catalog.load(name)
    # print(type(ds).__name__)
    print(type(obj))#.__name__)
    display(obj)
# Out:
# 2026-05-21 15:02:11,176 - kedro.io.data_catalog - INFO - Loading data from `vmm_abkowitz` (PickleDataSet)...
# <class 'vessel_manoeuvring_models.models.vmm.VMM'>
#  X_eq:
#    /           2          \                                             2
# m*\\dot{u} - r *x_G - r*v/ = X_{\dot{u}}*\dot{u} + X_{deltadelta}*delta  + X_{
#
#                           2                                            2
# rdelta}*delta*r + X_{rr}*r  + X_{thrust}*thrust + X_{udeltadelta}*delta *u + X
#
#                                 2              3           2
# _{urdelta}*delta*r*u + X_{urr}*r *u + X_{uuu}*u  + X_{uu}*u  + X_{uvdelta}*del
#
#                                     2
# ta*u*v + X_{uvr}*r*u*v + X_{uvv}*u*v  + X_{u}*u + X_{vdelta}*delta*v + X_{vr}*
#
#               2
# r*v + X_{vv}*v
#
#  Y:
#                                             2
# m*(\dot{r}*x_G + \dot{v} + r*u) = Y_{0uu}*u  + Y_{0u}*u + Y_{0} + Y_{\dot{r}}*
#
#                                                          3
# \dot{r} + Y_{\dot{v}}*\dot{v} + Y_{deltadeltadelta}*delta  + Y_{delta}*delta +
#
#                       2                        2            3
#  Y_{rdeltadelta}*delta *r + Y_{rrdelta}*delta*r  + Y_{rrr}*r  + Y_{r}*r + Y_{t
#
#
# hrustdelta}*delta*thrust + Y_{thrust}*thrust + Y_{udelta}*delta*u + Y_{ur}*r*u
#
#                       2              2            2
#  + Y_{uudelta}*delta*u  + Y_{uur}*r*u  + Y_{uuv}*u *v + Y_{uv}*u*v + Y_{vdelta
#
#             2                                      2                        2
# delta}*delta *v + Y_{vrdelta}*delta*r*v + Y_{vrr}*r *v + Y_{vvdelta}*delta*v
#
#              2            3
# + Y_{vvr}*r*v  + Y_{vvv}*v  + Y_{v}*v
#
#  N:
#                                                 2
# I_z*\dot{r} + m*x_G*(\dot{v} + r*u) = N_{0uu}*u  + N_{0u}*u + N_{0} + N_{\dot{
#
#                                                              3
# r}}*\dot{r} + N_{\dot{v}}*\dot{v} + N_{deltadeltadelta}*delta  + N_{delta}*del
#
#                           2                        2            3
# ta + N_{rdeltadelta}*delta *r + N_{rrdelta}*delta*r  + N_{rrr}*r  + N_{r}*r +
#
#
# N_{thrustdelta}*delta*thrust + N_{thrust}*thrust + N_{udelta}*delta*u + N_{ur}
#
#                           2              2            2
# *r*u + N_{uudelta}*delta*u  + N_{uur}*r*u  + N_{uuv}*u *v + N_{uv}*u*v + N_{vd
#
#                 2                                      2
# eltadelta}*delta *v + N_{vrdelta}*delta*r*v + N_{vrr}*r *v + N_{vvdelta}*delta
#
#   2              2            3
# *v  + N_{vvr}*r*v  + N_{vvv}*v  + N_{v}*v
# 2026-05-21 15:02:11,199 - kedro.io.data_catalog - INFO - Loading data from `vmm_linear` (PickleDataSet)...
# <class 'vessel_manoeuvring_models.models.vmm.VMM'>
#  X_eq:
#  \dot{u}*m = X_{\dot{u}}*\dot{u} + X_{delta}*delta + X_{r}*r + X_{u}*u + X_{v}*
# v
#
#  Y:
#  m*(U*r + \dot{r}*x_G + \dot{v}) = Y_{\dot{r}}*\dot{r} + Y_{\dot{v}}*\dot{v} +
# Y_{delta}*delta + Y_{r}*r + Y_{u}*u + Y_{v}*v
#
#  N:
#  I_z*\dot{r} + m*x_G*(U*r + \dot{v}) = N_{\dot{r}}*\dot{r} + N_{\dot{v}}*\dot{v
# } + N_{delta}*delta + N_{r}*r + N_{u}*u + N_{v}*v
